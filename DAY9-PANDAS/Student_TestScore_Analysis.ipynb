# %% [markdown]
# Student Test Score Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Create sample data

# %%
np.random.seed(42)
data = pd.DataFrame({
    'School': np.random.choice(['School A', 'School B', 'School C'], 150),
    'Score': np.random.normal(75, 10, 150)  # mean=75, std=10
})

# %% [markdown]
# Overall score distribution

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data['Score'], kde=True, bins=20, color='skyblue')
plt.title('Overall Test Score Distribution')
plt.xlabel('Score')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# Compare scores by school

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='School', y='Score', data=data, palette='Set2')
plt.title('Test Score Comparison by School')
plt.xlabel('School')
plt.ylabel('Score')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16864\1616045333.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='School', y='Score', data=data, palette='Set2')
