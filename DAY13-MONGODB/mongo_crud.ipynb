# %%
use shopDB
db.products.insertOne({
  product_id: 101,
  name: "Keyboard",
  category: "Electronics",
  price: 45,
  stock: 20
})
db.products.insertMany([
  { product_id: 102, name: "Mouse", category: "Electronics", price: 25, stock: 50 },
  { product_id: 103, name: "Monitor", category: "Electronics", price: 120, stock: 15 },
  { product_id: 104, name: "Chair", category: "Furniture", price: 80, stock: 10 }
])
db.products.find()
db.products.find({ price: { $gt: 50 } })
db.products.findOne({ name: "Keyboard" })
db.products.updateOne(
  { name: "Monitor" },
  { $set: { price: 130 } }
)
db.products.updateMany(
  { category: "Electronics" },
  { $inc: { price: 10 } }
)
db.products.deleteOne({ name: "Chair" })
db.products.deleteMany({ stock: { $lt: 15 } })
